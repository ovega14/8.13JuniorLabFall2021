# %% [markdown]
# **Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import modplot
import os

# %% [markdown]
# **Get the Data**

# %%
base_dir = 'C:\\Users\\vega0\\Documents\\Academics\\MIT Course Materials\\Course 8 Physics\\8.13 Junior Physics Lab\\Fall 2021\\Experiment Sequences\\Relativistic Dynamics'
dir_data = base_dir + '\\Data'

# %%
# load in the spreadsheet with the count-rate maximizing voltage
df = pd.read_excel('count_rate_maximizing_voltages.xlsx')

bs = df['Magnetic Field (G)']
berrs = df['B Uncertainty']
vs = df['Voltage (kV)']
verrs = df['V Uncertainty']

# %% [markdown]
# **Plot the Data and Find Linear Relationship**

# %%
# plotting parameters
save = False
mpl.rcParams['figure.dpi'] = 300
mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')

# %%
fig, [ax] = modplot.axes(ratio_plot=False, xlim=(59,120), ylim=(2,4.6), 
                         xlabel='Magnetic Field $B$ [Gauss]', 
                         ylabel='Count Rate-Maximizing Voltage $V$ [kiloVolts]')

# data
ax.errorbar(bs, vs, xerr=berrs, yerr=verrs, label='Data', color='red', capthick=0.5,
           elinewidth=0.5, capsize=1, ls='none')

# the linear fit
def y(x):
    y = 0.0502*x-1.0588
    return y
x = np.linspace(60,120,100)
ax.plot(x, y(x), lw=0.5, color='purple', label='Linear Fit')

ax.legend(loc='upper right', numpoints=1)

modplot.stamp(0.05, 0.72, ax=ax, delta_y=0.05, 
         line_0='$V(B)=c_{0}+c_{1}B$',
         line_1='$\chi^{2}=0.00906$')

# %%
# chi-square
def chisq(x, y, data):
    return np.sum((data-y(x))**2/y(x)**2)

chi2 = chisq(bs, y, vs)

# %%
chi2
# Out:
# 0.009062733917719924

# %%
vs
# Out:
# 0    4.0
# 1    4.5
# 2    5.0
# 3    3.3
# 4    2.9
# 5    2.4
# 6    2.1
# Name: Voltage (kV), dtype: float64

# %%
y(bs)
# Out:
# 0    3.96120
# 1    4.46320
# 2    4.94512
# 3    3.46422
# 4    2.95720
# 5    2.45520
# 6    1.95320
# Name: Magnetic Field (G), dtype: float64

# %%
vs-y(bs)
# Out:
# 0    0.03880
# 1    0.03680
# 2    0.05488
# 3   -0.16422
# 4   -0.05720
# 5   -0.05520
# 6    0.14680
# dtype: float64

# %%
(vs-y(bs))**2
# Out:
# 0    0.001505
# 1    0.001354
# 2    0.003012
# 3    0.026968
# 4    0.003272
# 5    0.003047
# 6    0.021550
# dtype: float64
