# %% [markdown]
# **Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import modplot
import os

# %% [markdown]
# **Get all of the Calibration Data**

# %%
base_dir = 'C:\\Users\\vega0\\Documents\\Academics\\MIT Course Materials\\Course 8 Physics\\8.13 Experimental Physics 1\\Fall 2021\\Experiment Sequences\\Relativistic Dynamics'

# %%
dir_data = base_dir + '\\Data\\Barium 133 Calibrations'

# %%
os.chdir(dir_data)

# %%
os.listdir()
# Out:
# ['ba133_10-07-2021_day9.Spe',
#  'ba133_10-12-2021_day10.Spe',
#  'ba133_10-14-2021_day11.Spe',
#  'ba133_newamp_10-07-2021_day9.Spe']

# %% [markdown]
# Day 9, Amp 1

# %%
day9_ba133 = os.listdir()[0]
f9 = open(day9_ba133, 'r')
data = f9.readlines()

counts9 = []
for line in data[12:2060]:
    newline = line.replace('\n', ' ')
    count = float(newline)
    counts9.append(count)

# %% [markdown]
# Day 9, Amp 2

# %%
day9_amp2_ba133 = os.listdir()[3]

f9_2 = open(day9_amp2_ba133, 'r')
data = f9_2.readlines()

counts9_2 = []
for line in data[12:2060]:
    newline = line.replace('\n', ' ')
    count = float(newline)
    counts9_2.append(count)

# %% [markdown]
# Day 10

# %%
day10_ba133 = os.listdir()[1]

f10 = open(day10_ba133, 'r')
data = f10.readlines()

counts10 = []
for line in data[12:2060]:
    newline = line.replace('\n', ' ')
    count = float(newline)
    counts10.append(count)

# %% [markdown]
# Day 11

# %%
day11_ba133 = os.listdir()[2]

f11 = open(day11_ba133, 'r')
data = f11.readlines()

counts11 = []
for line in data[12:2060]:
    newline = line.replace('\n', ' ')
    count = float(newline)
    counts11.append(count)

# %% [markdown]
# **Plot and Examine the Spectra**

# %%
# plotting parameters
save = False
mpl.rcParams['figure.dpi'] = 300
mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')

# %% [markdown]
# Day 9, Amp 1

# %%
plt.plot(counts9)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Raw Counts')
plt.xlabel('Channel Number')
# Out:
# Text(0.5, 0, 'Channel Number')

# %% [markdown]
# Day 9, Amp 2

# %%
plt.plot(counts9_2)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Raw Counts')
plt.xlabel('Channel Number')
# Out:
# Text(0.5, 0, 'Channel Number')

# %% [markdown]
# Day 10

# %%
plt.plot(counts10)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Raw Counts')
plt.xlabel('Channel Number')
# Out:
# Text(0.5, 0, 'Channel Number')

# %% [markdown]
# Day 11

# %%
plt.plot(counts11)
#plt.xscale('log')
plt.yscale('log')
plt.ylabel('Raw Counts')
plt.xlabel('Channel Number')
# Out:
# Text(0.5, 0, 'Channel Number')
